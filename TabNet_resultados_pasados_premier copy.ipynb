# %%
from pytorch_tabnet.tab_model import TabNetClassifier

import os
import torch
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
 
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
historical_standings_pl = pd.read_csv('data/Premier/premier-league-standing-1993-2023.csv')

print(historical_standings_pl.columns)
# Out:
# Index(['Season_End_Year', 'Team', 'Rk', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD',
#        'Pts', 'Notes'],
#       dtype='object')

# %%
#columna Notes no aporta.
historical_standings_pl = historical_standings_pl.drop(columns=['Notes'])
print(historical_standings_pl.columns)
# Out:
# Index(['Season_End_Year', 'Team', 'Rk', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD',
#        'Pts'],
#       dtype='object')

# %%
#Revisamos la cantidad y los nombres de los equipos
print(historical_standings_pl['Team'].unique())
print("\ncantidad: ", len(historical_standings_pl['Team'].unique()))
# Out:
# ['Arsenal' 'Aston Villa' 'Blackburn' 'Chelsea' 'Coventry City'
#  'Crystal Palace' 'Everton' 'Ipswich Town' 'Leeds United' 'Liverpool'
#  'Manchester City' 'Manchester Utd' 'Middlesbrough' 'Norwich City'
#  "Nott'ham Forest" 'Oldham Athletic' 'QPR' 'Sheffield Utd'
#  'Sheffield Weds' 'Southampton' 'Tottenham' 'Wimbledon' 'Newcastle Utd'
#  'Swindon Town' 'West Ham' 'Leicester City' 'Bolton' 'Derby County'
#  'Sunderland' 'Barnsley' 'Charlton Ath' 'Bradford City' 'Watford' 'Fulham'
#  'Birmingham City' 'West Brom' 'Portsmouth' 'Wolves' 'Wigan Athletic'
#  'Reading' 'Hull City' 'Stoke City' 'Burnley' 'Blackpool' 'Swansea City'
#  'Cardiff City' 'Bournemouth' 'Brighton' 'Huddersfield' 'Brentford']
#
# cantidad:  50

# %%
#Cargar archivo de los partidos
matches = pd.read_csv('data/Premier/premier-league-matches-1993-2023.csv')

print(matches.columns)
# Out:
# Index(['Season_End_Year', 'Wk', 'Date', 'Home', 'HomeGoals', 'AwayGoals',
#        'Away', 'FTR'],
#       dtype='object')

# %%
#Revisan los equipos
print("equipos locales: ", matches['Home'].unique())
print("\ncantidad locales: ", len(matches['Home'].unique()))

print("\n\nequipos visitantes: ", matches['Away'].unique())
print("\ncantidad visitantes: ", len(matches['Away'].unique()))
# Out:
# equipos locales:  ['Coventry City' 'Leeds United' 'Sheffield Utd' 'Crystal Palace' 'Arsenal'
#  'Ipswich Town' 'Everton' 'Southampton' 'Chelsea' "Nott'ham Forest"
#  'Manchester City' 'Blackburn' 'Wimbledon' 'Tottenham' 'Liverpool'
#  'Aston Villa' 'Oldham Athletic' 'Middlesbrough' 'Norwich City' 'QPR'
#  'Manchester Utd' 'Sheffield Weds' 'Newcastle Utd' 'West Ham'
#  'Swindon Town' 'Leicester City' 'Bolton' 'Sunderland' 'Derby County'
#  'Barnsley' 'Charlton Ath' 'Watford' 'Bradford City' 'Fulham'
#  'Birmingham City' 'West Brom' 'Portsmouth' 'Wolves' 'Wigan Athletic'
#  'Reading' 'Hull City' 'Stoke City' 'Burnley' 'Blackpool' 'Swansea City'
#  'Cardiff City' 'Bournemouth' 'Brighton' 'Huddersfield' 'Brentford']
#
# cantidad locales:  50
#
#
# equipos visitantes:  ['Middlesbrough' 'Wimbledon' 'Manchester Utd' 'Blackburn' 'Norwich City'
#  'Aston Villa' 'Sheffield Weds' 'Tottenham' 'Oldham Athletic' 'Liverpool'
#  'QPR' 'Arsenal' 'Ipswich Town' 'Coventry City' 'Sheffield Utd'
#  'Leeds United' 'Crystal Palace' 'Manchester City' 'Chelsea' 'Southampton'
#  'Everton' "Nott'ham Forest" 'Swindon Town' 'West Ham' 'Newcastle Utd'
#  'Leicester City' 'Bolton' 'Derby County' 'Sunderland' 'Barnsley'
#  'Charlton Ath' 'Bradford City' 'Watford' 'Fulham' 'West Brom'
#  'Birmingham City' 'Wolves' 'Portsmouth' 'Wigan Athletic' 'Reading'
#  'Stoke City' 'Hull City' 'Burnley' 'Blackpool' 'Swansea City'
#  'Cardiff City' 'Bournemouth' 'Huddersfield' 'Brighton' 'Brentford']
#
# cantidad visitantes:  50

# %%
#Se eliminan los resultados de la temporada 2023 de las historical standings
historical_standings_pl = historical_standings_pl[historical_standings_pl['Season_End_Year'] != 2023]

#Revisar seasons
print(historical_standings_pl['Season_End_Year'].unique())
#Se revisan los equipos d nuevo
print(historical_standings_pl['Team'].unique())
print("\ncantidad: ", len(historical_standings_pl['Team'].unique()))
# Out:
# [1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
#  2021 2022]
# ['Arsenal' 'Aston Villa' 'Blackburn' 'Chelsea' 'Coventry City'
#  'Crystal Palace' 'Everton' 'Ipswich Town' 'Leeds United' 'Liverpool'
#  'Manchester City' 'Manchester Utd' 'Middlesbrough' 'Norwich City'
#  "Nott'ham Forest" 'Oldham Athletic' 'QPR' 'Sheffield Utd'
#  'Sheffield Weds' 'Southampton' 'Tottenham' 'Wimbledon' 'Newcastle Utd'
#  'Swindon Town' 'West Ham' 'Leicester City' 'Bolton' 'Derby County'
#  'Sunderland' 'Barnsley' 'Charlton Ath' 'Bradford City' 'Watford' 'Fulham'
#  'Birmingham City' 'West Brom' 'Portsmouth' 'Wolves' 'Wigan Athletic'
#  'Reading' 'Hull City' 'Stoke City' 'Burnley' 'Blackpool' 'Swansea City'
#  'Cardiff City' 'Bournemouth' 'Brighton' 'Huddersfield' 'Brentford']
#
# cantidad:  50

# %%
#Se elimina la temporada 1993 de los partidos porque no hay datos de la tabla de posiciones de la temp anterior.
matches = matches[matches['Season_End_Year'] != 1993]

# %%
#Comparar los equipos de los partidos con los equipos de las standings
teams_matches_home = matches['Home'].unique()
teams_standings = historical_standings_pl['Team'].unique()

teams_not_in_standings = []
for team in teams_matches_home:
    if team not in teams_standings:
        teams_not_in_standings.append(team)

print("Equipos en partidos pero no en standings: ", teams_not_in_standings)

#Comparamos las standings con partidos
teams_not_in_matches = []
for team in teams_standings:
    if team not in teams_matches_home:
        teams_not_in_matches.append(team)

print("Equipos en standings pero no en partidos: ", teams_not_in_matches)
# Out:
# Equipos en partidos pero no en standings:  []
# Equipos en standings pero no en partidos:  []

# %%
#Ahora, se crea una columna de start year en las standings para hacer el merge.
historical_standings_pl['Season_Start_Year'] = historical_standings_pl['Season_End_Year'] + 1

#Se elimina la columna de season end year
historical_standings_pl = historical_standings_pl.drop(columns=['Season_End_Year'])
print(historical_standings_pl.head)
print(historical_standings_pl['Rk'].unique())
# Out:
# <bound method NDFrame.head of               Team  Rk  MP   W   D   L  GF  GA  GD  Pts  Season_Start_Year
# 0          Arsenal  10  42  15  11  16  40  38   2   56               1994
# 1      Aston Villa   2  42  21  11  10  57  40  17   74               1994
# 2        Blackburn   4  42  20  11  11  68  46  22   71               1994
# 3          Chelsea  11  42  14  14  14  51  54  -3   56               1994
# 4    Coventry City  15  42  13  13  16  52  57  -5   52               1994
# ..             ...  ..  ..  ..  ..  ..  ..  ..  ..  ...                ...
# 601    Southampton  15  38   9  13  16  43  67 -24   40               2023
# 602      Tottenham   4  38  22   5  11  69  40  29   71               2023
# 603        Watford  19  38   6   5  27  34  77 -43   23               2023
# 604       West Ham   7  38  16   8  14  60  51   9   56               2023
# 605         Wolves  10  38  15   6  17  38  43  -5   51               2023
#
# [606 rows x 11 columns]>
# [10  2  4 11 15 20 13 16 17  6  9  1 21  3 22 19  5 14  7 18  8 12]

# %%
#Seleccionar equipos con Rk menor que 20.
rk_over_20 = historical_standings_pl[historical_standings_pl['Rk'] > 20]
print(rk_over_20)
# Out:
#                Team  Rk  MP   W   D   L  GF   GA  GD  Pts  Season_Start_Year
# 12    Middlesbrough  21  42  11  11  20  54   75 -21   44               1994
# 14  Nott'ham Forest  22  42  10  10  22  41   62 -21   40               1994
# 35  Oldham Athletic  21  42   9  13  20  42   68 -26   40               1995
# 40     Swindon Town  22  42   5  15  22  47  100 -53   30               1995
# 51     Ipswich Town  22  42   7   6  29  36   93 -57   27               1996
# 53   Leicester City  21  42   6  11  25  45   80 -35   29               1996

# %%
#Solo nos importan las columnas de la posición y los puntos
historical_standings_pl = historical_standings_pl[['Team', 'Season_Start_Year', 'Rk', 'Pts']]

#merge de los partidos con las standings del local
matches = matches.merge(historical_standings_pl, left_on=['Home', 'Season_End_Year'], right_on=['Team', 'Season_Start_Year'], how='left')

#Se renombran las columnas last_season
matches = matches.rename(columns={'Rk': 'Position_last_year_home', 'Pts': 'Points_last_year_home'})

#Se eliminan las columnas de team y season start year
matches = matches.drop(columns=['Team', 'Season_Start_Year'])

#merge de los partidos con las standings del visitante
matches = matches.merge(historical_standings_pl, left_on=['Away', 'Season_End_Year'], right_on=['Team', 'Season_Start_Year'], how='left')

#Se renombran las columnas last_season
matches = matches.rename(columns={'Rk': 'Position_last_year_away', 'Pts': 'Points_last_year_away'})

#Se eliminan las columnas de team y season start year
matches = matches.drop(columns=['Team', 'Season_Start_Year'])

print(matches.columns)
#print el primer partido
print(matches.iloc[0])
# Out:
# Index(['Season_End_Year', 'Wk', 'Date', 'Home', 'HomeGoals', 'AwayGoals',
#        'Away', 'FTR', 'Position_last_year_home', 'Points_last_year_home',
#        'Position_last_year_away', 'Points_last_year_away'],
#       dtype='object')
# Season_End_Year                      1994
# Wk                                      1
# Date                           1993-08-14
# Home                            Liverpool
# HomeGoals                               2
# AwayGoals                               0
# Away                       Sheffield Weds
# FTR                                     H
# Position_last_year_home               6.0
# Points_last_year_home                59.0
# Position_last_year_away               7.0
# Points_last_year_away                59.0
# Name: 0, dtype: object

# %% [markdown]
# Si no tiene posición en la temporada pasada, es porque el equipo **ascendió de categoría**. Se pone la posición 18.

# %%
matches['Position_last_year_home'] = matches['Position_last_year_home'].fillna(18)
print(matches['Position_last_year_home'].unique())

matches['Position_last_year_away'] = matches['Position_last_year_away'].fillna(18)
print(matches['Position_last_year_away'].unique())
# Out:
# [ 6. 11.  2. 19. 10.  9. 18. 14.  3.  8. 12. 17. 16. 13.  1.  7.  4. 15.
#   5.]
# [ 7.  4.  5. 16. 15. 17.  8. 18. 13. 12.  1. 10. 11.  9. 14.  2.  3. 19.
#   6.]

# %% [markdown]
# Para el tema de los puntos vacios, se rellenan con el puntaje que tuvo el puesto 17 ya que es el último puesto que no desciende.

# %%
seasons = matches['Season_End_Year'].unique()

for season in seasons:
    
    points_17 = historical_standings_pl[(historical_standings_pl['Season_Start_Year'] == season) & (historical_standings_pl['Rk'] == 17.0)]['Pts']

    points_17 = points_17.values[0]
    matches.loc[(matches['Season_End_Year'] == season) & (matches['Points_last_year_home'].isnull()), 'Points_last_year_home'] = points_17
    matches.loc[(matches['Season_End_Year'] == season) & (matches['Points_last_year_away'].isnull()), 'Points_last_year_away'] = points_17

print(matches.iloc[0])
print(matches[matches['Points_last_year_home'].isnull()])
print(matches[matches['Points_last_year_away'].isnull()])
# Out:
# Season_End_Year                      1994
# Wk                                      1
# Date                           1993-08-14
# Home                            Liverpool
# HomeGoals                               2
# AwayGoals                               0
# Away                       Sheffield Weds
# FTR                                     H
# Position_last_year_home               6.0
# Points_last_year_home                59.0
# Position_last_year_away               7.0
# Points_last_year_away                59.0
# Name: 0, dtype: object
# Empty DataFrame
# Columns: [Season_End_Year, Wk, Date, Home, HomeGoals, AwayGoals, Away, FTR, Position_last_year_home, Points_last_year_home, Position_last_year_away, Points_last_year_away]
# Index: []
# Empty DataFrame
# Columns: [Season_End_Year, Wk, Date, Home, HomeGoals, AwayGoals, Away, FTR, Position_last_year_home, Points_last_year_home, Position_last_year_away, Points_last_year_away]
# Index: []

# %% [markdown]
# Se normaliza los nombres de las columnas: Home -> Team_home, Away -> Team_away, HomeGoals -> Goals_home, awayGoals -> Goals_away.

# %%
matches = matches.rename(columns={'Home': 'Team_home', 'Away': 'Team_away', 'HomeGoals': 'Goals_home', 'AwayGoals': 'Goals_away'})
#Se elimina columna FTR
matches = matches.drop(columns=['FTR'])
matches.columns
# Out:
# Index(['Season_End_Year', 'Wk', 'Date', 'Team_home', 'Goals_home',
#        'Goals_away', 'Team_away', 'Position_last_year_home',
#        'Points_last_year_home', 'Position_last_year_away',
#        'Points_last_year_away'],
#       dtype='object')

# %%
#Reordenar columnas de matches: 'Season_End_Year', 'Wk', 'Date', Team_home, Team_away, Goals_home, Goals_away, Position_last_year_home, Position_last_year_away, Points_last_year_home, Points_last_year_away
matches = matches[['Season_End_Year', 'Wk', 'Date', 'Team_home', 'Team_away', 'Goals_home', 'Goals_away', 'Position_last_year_home', 'Position_last_year_away', 'Points_last_year_home', 'Points_last_year_away']]
matches.columns
# Out:
# Index(['Season_End_Year', 'Wk', 'Date', 'Team_home', 'Team_away', 'Goals_home',
#        'Goals_away', 'Position_last_year_home', 'Position_last_year_away',
#        'Points_last_year_home', 'Points_last_year_away'],
#       dtype='object')

# %% [markdown]
# Se dividen los partidos por temporada.

# %%
seasons = []
seasons_year = matches['Season_End_Year'].unique()

for season in seasons_year:
    season_data = matches[matches['Season_End_Year'] == season]
    season_data = season_data.drop(columns=['Season_End_Year'])
    season_data = season_data.drop(columns=['Date'])
    seasons.append(season_data)
    print(season_data.shape)
# Out:
# (462, 9)
# (462, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)
# (380, 9)

# %% [markdown]
# Se generan las tablas para cada temporada.

# %%
def remove_suffix(item):
    return item.replace("_home", "").replace("_away", "")

column = [remove_suffix(item) for item in matches.columns]
columnas = []
[columnas.append(x) for x in column if x not in columnas]
columnas.remove("Wk")
columnas.remove("Season_End_Year")
columnas.remove("Date")
columnas.remove("Team")
columnas[0] = "score_prom"
print(columnas)
print(len(columnas))
# Out:
# ['score_prom', 'Position_last_year', 'Points_last_year']
# 3

# %%
columnas.append("wins")
columnas.append("ties")
columnas.append("losses")
columnas.append("total_goals")
columnas.append("total_goals_conceded")
columnas.append("points")
columnas.append("streak")
columnas.append("wins_in_last_5_matches")
columnas.append("ties_in_last_5_matches")
columnas.append("losses_in_last_5_matches")

# %%
tablas = []

for torneo, i in zip(seasons, range(len(seasons))):
    equipos = torneo["Team_home"].unique()
    equipos2 = torneo["Team_away"].unique()
    stats = columnas

    tabla = {}

    for equipo in equipos:

        tabla[equipo] = dict.fromkeys(stats, 0)
        tabla[equipo]["last_5_matches"] = list()

    tablas.append(tabla)

print(stats)
# Out:
# ['score_prom', 'Position_last_year', 'Points_last_year', 'wins', 'ties', 'losses', 'total_goals', 'total_goals_conceded', 'points', 'streak', 'wins_in_last_5_matches', 'ties_in_last_5_matches', 'losses_in_last_5_matches']

# %%
new_stats = ["wins",
"ties",
"losses",
"total_goals",
"total_goals_conceded",
"points",
"streak",
"wins_in_last_5_matches",
"ties_in_last_5_matches",
"losses_in_last_5_matches"]
procesated_matches_columns = list(seasons[0].columns)
procesated_matches_columns.insert(5, "score_prom_away")
procesated_matches_columns.insert(5, "score_prom_home")

for stat in new_stats:
    procesated_matches_columns.append(f"{stat}_home")
    procesated_matches_columns.append(f"{stat}_away")

procesated_matches = pd.DataFrame(columns = procesated_matches_columns)

procesated_matches.head()
# Out:
# Empty DataFrame
# Columns: [Wk, Team_home, Team_away, Goals_home, Goals_away, score_prom_home, score_prom_away, Position_last_year_home, Position_last_year_away, Points_last_year_home, Points_last_year_away, wins_home, wins_away, ties_home, ties_away, losses_home, losses_away, total_goals_home, total_goals_away, total_goals_conceded_home, total_goals_conceded_away, points_home, points_away, streak_home, streak_away, wins_in_last_5_matches_home, wins_in_last_5_matches_away, ties_in_last_5_matches_home, ties_in_last_5_matches_away, losses_in_last_5_matches_home, losses_in_last_5_matches_away]
# Index: []
#
# [0 rows x 31 columns]

# %%
contador = 0
for torneo, i in zip(seasons, range(len(seasons))):
    torneo.sort_values(by='Wk', inplace=True)
    tabla = tablas[i]
    for index in torneo.index:
    
        """Escribir info en el nuevo df de partidos con la información hasta el partido la cual esta almacenada en 'tabla'"""
        match = torneo.loc[index]

        team_home = match["Team_home"]
        team_away = match["Team_away"]

        stats_home = tabla[team_home]
        stats_away = tabla[team_away]

        fila = []
        fila.append(match["Wk"])
        fila.append(team_home)
        fila.append(team_away)
        fila.append(match["Goals_home"])
        fila.append(match["Goals_away"])

        for stat in stats:
            fila.append(tabla[team_home][stat])
            fila.append(tabla[team_away][stat])

        procesated_matches.loc[len(procesated_matches)] = fila
        
        
        """ Actualizar la tabla con lo que realmente ocurrió en ese partido"""

        matches_played_home = tabla[team_home]["wins"] + tabla[team_home]["ties"] + tabla[team_home]["losses"]+1
        matches_played_away = tabla[team_away]["wins"] + tabla[team_away]["ties"] + tabla[team_away]["losses"]+1
        
        ## stats promediadas:
        for stat in stats[:stats.index("wins")]:
            if stat == "score_prom":
                tabla[team_home][stat] = (tabla[team_home][stat]*(matches_played_home-1) + match["Goals_home"])/matches_played_home
                tabla[team_away][stat] = (tabla[team_away][stat]*(matches_played_away-1) + match["Goals_away"])/matches_played_away


        if contador == 0:
            print(match["Position_last_year_home"])
            print(match["Position_last_year_away"])
        contador = 1
        ## stats acumuladas
        
        empate = False
        if match["Goals_home"] > match["Goals_away"]:

            #victorias / derrotas
            tabla[team_home]["wins"] += 1
            tabla[team_away]["losses"] += 1

            #goles a favor
            tabla[team_home]["total_goals"] += match["Goals_home"]
            tabla[team_away]["total_goals"] += match["Goals_away"]

            #goles en contra
            tabla[team_home]["total_goals_conceded"] += match["Goals_away"]
            tabla[team_away]["total_goals_conceded"] += match["Goals_home"]

            #puntos
            tabla[team_home]["points"] += 3

            # racha
            tabla[team_home]["streak"] += 1
            tabla[team_away]["streak"] = 0

            # ultimos 5 partidos
            if len(tabla[team_home]["last_5_matches"]) == 5:
                tabla[team_home]["last_5_matches"].pop(0)
            if len(tabla[team_away]["last_5_matches"]) == 5:
                tabla[team_away]["last_5_matches"].pop(0)

            tabla[team_home]["last_5_matches"].append("W")
            tabla[team_away]["last_5_matches"].append("L")


        elif match["Goals_home"] < match["Goals_away"]:

            #victorias / derrotas
            tabla[team_away]["wins"] += 1
            tabla[team_home]["losses"] += 1

            #goles a favor
            tabla[team_away]["total_goals"] += match["Goals_away"]
            tabla[team_home]["total_goals"] += match["Goals_home"]

            #goles en contra
            tabla[team_away]["total_goals_conceded"] += match["Goals_home"]
            tabla[team_home]["total_goals_conceded"] += match["Goals_away"]

            #puntos
            tabla[team_away]["points"] += 3

            # racha
            tabla[team_away]["streak"] += 1
            tabla[team_home]["streak"] = 0

            # ultimos 5 partidos
            if len(tabla[team_home]["last_5_matches"]) == 5:
                tabla[team_home]["last_5_matches"].pop(0)
            if len(tabla[team_away]["last_5_matches"]) == 5:
                tabla[team_away]["last_5_matches"].pop(0)

            tabla[team_away]["last_5_matches"].append("W")
            tabla[team_home]["last_5_matches"].append("L")

        else:
            #empate
            tabla[team_home]["ties"] += 1
            tabla[team_away]["ties"] += 1

            #goles a favor
            tabla[team_home]["total_goals"] += match["Goals_home"]
            tabla[team_away]["total_goals"] += match["Goals_away"]

            #goles en contra
            tabla[team_home]["total_goals_conceded"] += match["Goals_away"]
            tabla[team_away]["total_goals_conceded"] += match["Goals_home"]

            #puntos
            tabla[team_home]["points"] += 1
            tabla[team_away]["points"] += 1

            # racha
            tabla[team_away]["streak"] += 1
            tabla[team_home]["streak"] += 1

            # ultimos 5 partidos
            if len(tabla[team_home]["last_5_matches"]) == 5:
                tabla[team_home]["last_5_matches"].pop(0)
            if len(tabla[team_away]["last_5_matches"]) == 5:
                tabla[team_away]["last_5_matches"].pop(0)

            tabla[team_away]["last_5_matches"].append("T")
            tabla[team_home]["last_5_matches"].append("T")

        tabla[team_home]["wins_in_last_5_matches"] = tabla[team_home]["last_5_matches"].count("W")
        tabla[team_home]["ties_in_last_5_matches"] = tabla[team_home]["last_5_matches"].count("T")
        tabla[team_home]["losses_in_last_5_matches"] = tabla[team_home]["last_5_matches"].count("L")

        tabla[team_away]["wins_in_last_5_matches"] = tabla[team_away]["last_5_matches"].count("W")
        tabla[team_away]["ties_in_last_5_matches"] = tabla[team_away]["last_5_matches"].count("T")
        tabla[team_away]["losses_in_last_5_matches"] = tabla[team_away]["last_5_matches"].count("L")

        tabla[team_home]["Points_last_year"] = match["Points_last_year_home"]
        tabla[team_away]["Points_last_year"] = match["Points_last_year_away"]

        tabla[team_home]["Position_last_year"] = match["Position_last_year_home"]
        tabla[team_away]["Position_last_year"] = match["Position_last_year_away"]
# Out:
# 6.0
# 7.0

# %%
procesated_matches.tail()
# Out:
#        Wk       Team_home        Team_away  Goals_home  Goals_away  \
# 11559  38     Southampton        Liverpool           4           4
# 11560  38         Everton      Bournemouth           1           0
# 11561  38  Leicester City         West Ham           2           1
# 11562  38     Aston Villa         Brighton           2           1
# 11563  38       Brentford  Manchester City           1           0
#
#        score_prom_home  score_prom_away  Position_last_year_home  \
# 11559         0.864865         1.918919                     15.0
# 11560         0.891892         1.000000                     16.0
# 11561         1.324324         1.108108                      8.0
# 11562         1.324324         1.918919                     14.0
# 11563         1.540541         2.540541                     13.0
#
#        Position_last_year_away  Points_last_year_home  ...  points_home  \
# 11559                      2.0                   40.0  ...           24
# 11560                     18.0                   39.0  ...           33
# 11561                      7.0                   52.0  ...           31
# 11562                      9.0                   45.0  ...           58
# 11563                      1.0                   46.0  ...           56
#
#        points_away  streak_home  streak_away  wins_in_last_5_matches_home  \
# 11559           66            0            8                            0
# 11560           39            1            0                            1
# 11561           40            1            1                            0
# 11562           62            2            2                            2
# 11563           89            2           15                            4
#
#        wins_in_last_5_matches_away  ties_in_last_5_matches_home  \
# 11559                            4                            0
# 11560                            2                            2
# 11561                            2                            3
# 11562                            3                            1
# 11563                            5                            0
#
#        ties_in_last_5_matches_away  losses_in_last_5_matches_home  \
# 11559                            1                              5
# 11560                            0                              2
# 11561                            0                              2
# 11562                            0                              2
# 11563                            0                              1
#
#        losses_in_last_5_matches_away
# 11559                              0
# 11560                              3
# 11561                              3
# 11562                              2
# 11563                              0
#
# [5 rows x 31 columns]

# %%
#Usamos el GPU si esta disponible, mps porque es apple silicon.
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f"using {device}")
# Out:
# using mps

# %%
matches = procesated_matches

#Aqui agrega la columna de resultados

results = []

for index in matches.index:

    match = matches.loc[index]
    if match["Goals_home"] > match["Goals_away"]:
        results.append(1)
    elif match["Goals_home"] < match["Goals_away"]:
        results.append(2)
    else:
        results.append(0)

matches["result"] = results
print(matches.tail())
# Out:
#        Wk       Team_home        Team_away  Goals_home  Goals_away  \
# 11559  38     Southampton        Liverpool           4           4
# 11560  38         Everton      Bournemouth           1           0
# 11561  38  Leicester City         West Ham           2           1
# 11562  38     Aston Villa         Brighton           2           1
# 11563  38       Brentford  Manchester City           1           0
#
#        score_prom_home  score_prom_away  Position_last_year_home  \
# 11559         0.864865         1.918919                     15.0
# 11560         0.891892         1.000000                     16.0
# 11561         1.324324         1.108108                      8.0
# 11562         1.324324         1.918919                     14.0
# 11563         1.540541         2.540541                     13.0
#
#        Position_last_year_away  Points_last_year_home  ...  points_away  \
# 11559                      2.0                   40.0  ...           66
# 11560                     18.0                   39.0  ...           39
# 11561                      7.0                   52.0  ...           40
# 11562                      9.0                   45.0  ...           62
# 11563                      1.0                   46.0  ...           89
#
#        streak_home  streak_away  wins_in_last_5_matches_home  \
# 11559            0            8                            0
# 11560            1            0                            1
# 11561            1            1                            0
# 11562            2            2                            2
# 11563            2           15                            4
#
#        wins_in_last_5_matches_away  ties_in_last_5_matches_home  \
# 11559                            4                            0
# 11560                            2                            2
# 11561                            2                            3
# 11562                            3                            1
# 11563                            5                            0
#
#        ties_in_last_5_matches_away  losses_in_last_5_matches_home  \
# 11559                            1                              5
# 11560                            0                              2
# 11561                            0                              2
# 11562                            0                              2
# 11563                            0                              1
#
#        losses_in_last_5_matches_away  result
# 11559                              0       0
# 11560                              3       1
# 11561                              3       1
# 11562                              2       1
# 11563                              0       1
#
# [5 rows x 32 columns]

# %%
#Cantidad de partidos por resultado (local, empate, visita)

for i in range(0,3):
    cantidad = matches[matches["result"]==i].shape[0]
    print(f"Resultado {i}, hay: {cantidad} partidos")
num = 5305/(2967+3292+5305)
print("azar, siempre al local:", num)
# Out:
# Resultado 0, hay: 2967 partidos
# Resultado 1, hay: 5305 partidos
# Resultado 2, hay: 3292 partidos
# azar, siempre al local: 0.4587512971290211

# %%
#Ahora, vamos a separar el último torneo

cant_partidos_ultima_temp = len(seasons[-1])

matches_train = matches.iloc[:-cant_partidos_ultima_temp]
matches_test = matches.iloc[-cant_partidos_ultima_temp:]

result_train = matches_train["result"]
result_test = matches_test["result"]
matches_train = matches_train.drop(columns = ["Team_home", "Team_away", "result", "Goals_home", "Goals_away", "Wk"])
matches_test = matches_test.drop(columns = ["Team_home", "Team_away", "result", "Goals_home", "Goals_away", "Wk"])

matches_train.tail(), matches_test.tail()
# Out:
# (       score_prom_home  score_prom_away  Position_last_year_home  \
#  11179         1.324324         1.540541                     14.0
#  11180         0.621622         1.729730                     18.0
#  11181         0.891892         1.135135                     17.0
#  11182         2.459459         1.000000                      3.0
#  11183         2.000000         0.891892                      4.0
#
#         Position_last_year_away  Points_last_year_home  Points_last_year_away  \
#  11179                      2.0                   44.0                   74.0
#  11180                      7.0                   39.0                   62.0
#  11181                     12.0                   39.0                   45.0
#  11182                     13.0                   69.0                   45.0
#  11183                     18.0                   67.0                   39.0
#
#         wins_home  wins_away  ties_home  ties_away  ...  points_home  \
#  11179         10         16         15         10  ...           45
#  11180          5         21          7          5  ...           22
#  11181          7         12         14         10  ...           35
#  11182         27         15          8          6  ...           89
#  11183         20          6         11          5  ...           71
#
#         points_away  streak_home  streak_away  wins_in_last_5_matches_home  \
#  11179           58            4            1                            2
#  11180           68            1            4                            0
#  11181           46            0            1                            2
#  11182           51           17            2                            4
#  11183           23            2            0                            2
#
#         wins_in_last_5_matches_away  ties_in_last_5_matches_home  \
#  11179                            2                            2
#  11180                            2                            1
#  11181                            3                            1
#  11182                            0                            1
#  11183                            0                            2
#
#         ties_in_last_5_matches_away  losses_in_last_5_matches_home  \
#  11179                            1                              1
#  11180                            2                              4
#  11181                            0                              2
#  11182                            2                              0
#  11183                            0                              1
#
#         losses_in_last_5_matches_away
#  11179                              2
#  11180                              1
#  11181                              2
#  11182                              3
#  11183                              5
#
#  [5 rows x 26 columns],
#         score_prom_home  score_prom_away  Position_last_year_home  \
#  11559         0.864865         1.918919                     15.0
#  11560         0.891892         1.000000                     16.0
#  11561         1.324324         1.108108                      8.0
#  11562         1.324324         1.918919                     14.0
#  11563         1.540541         2.540541                     13.0
#
#         Position_last_year_away  Points_last_year_home  Points_last_year_away  \
#  11559                      2.0                   40.0                   92.0
#  11560                     18.0                   39.0                   38.0
#  11561                      7.0                   52.0                   56.0
#  11562                      9.0                   45.0                   51.0
#  11563                      1.0                   46.0                   93.0
#
#         wins_home  wins_away  ties_home  ties_away  ...  points_home  \
#  11559          6         19          6          9  ...           24
#  11560          7         11         12          6  ...           33
#  11561          8         11          7          7  ...           31
#  11562         17         18          7          8  ...           58
#  11563         14         28         14          5  ...           56
#
#         points_away  streak_home  streak_away  wins_in_last_5_matches_home  \
#  11559           66            0            8                            0
#  11560           39            1            0                            1
#  11561           40            1            1                            0
#  11562           62            2            2                            2
#  11563           89            2           15                            4
#
#         wins_in_last_5_matches_away  ties_in_last_5_matches_home  \
#  11559                            4                            0
#  11560                            2                            2
#  11561                            2                            3
#  11562                            3                            1
#  11563                            5                            0
#
#         ties_in_last_5_matches_away  losses_in_last_5_matches_home  \
#  11559                            1                              5
#  11560                            0                              2
#  11561                            0                              2
#  11562                            0                              2
#  11563                            0                              1
#
#         losses_in_last_5_matches_away
#  11559                              0
#  11560                              3
#  11561                              3
#  11562                              2
#  11563                              0
#
#  [5 rows x 26 columns])

# %%
X = matches_train.to_numpy()
scaler = StandardScaler()
X_train = scaler.fit_transform(X)
y_train = result_train

X_test = scaler.transform(matches_test.to_numpy())
y_test = result_test

# %%
clf = TabNetClassifier(
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=1e-3),
    scheduler_params={"step_size":50,
                        "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    mask_type='entmax', # "sparsemax" "entmax"
    )
    
clf.fit(X_train, y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)], 
    eval_name=['train', 'valid'], 
    eval_metric=['accuracy'], 
    max_epochs=1000 , patience=100, 
    batch_size=28, drop_last=False)

pred = clf.predict(X_test)
# Out:
# /Users/gustavofernandez/Desktop/iPre-resultados-deportivos/env/lib/python3.8/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.26721 | train_accuracy: 0.44599 | valid_accuracy: 0.47895 |  0:00:04s
# epoch 1  | loss: 1.06558 | train_accuracy: 0.45771 | valid_accuracy: 0.45789 |  0:00:08s
# epoch 2  | loss: 1.04599 | train_accuracy: 0.4738  | valid_accuracy: 0.46842 |  0:00:12s
# epoch 3  | loss: 1.03572 | train_accuracy: 0.48364 | valid_accuracy: 0.51053 |  0:00:17s
# epoch 4  | loss: 1.03101 | train_accuracy: 0.4932  | valid_accuracy: 0.50263 |  0:00:21s
# epoch 5  | loss: 1.02194 | train_accuracy: 0.49946 | valid_accuracy: 0.51053 |  0:00:25s
# epoch 6  | loss: 1.02159 | train_accuracy: 0.50277 | valid_accuracy: 0.52368 |  0:00:30s
# epoch 7  | loss: 1.01591 | train_accuracy: 0.5076  | valid_accuracy: 0.52105 |  0:00:34s
# epoch 8  | loss: 1.0147  | train_accuracy: 0.50653 | valid_accuracy: 0.51842 |  0:00:39s
# epoch 9  | loss: 1.01318 | train_accuracy: 0.50975 | valid_accuracy: 0.50263 |  0:00:43s
# epoch 10 | loss: 1.0108  | train_accuracy: 0.50948 | valid_accuracy: 0.51316 |  0:00:47s
# epoch 11 | loss: 1.00698 | train_accuracy: 0.51046 | valid_accuracy: 0.51053 |  0:00:52s
# epoch 12 | loss: 1.00613 | train_accuracy: 0.50984 | valid_accuracy: 0.51579 |  0:00:56s
# epoch 13 | loss: 1.00988 | train_accuracy: 0.51144 | valid_accuracy: 0.51316 |  0:01:00s
# epoch 14 | loss: 1.00657 | train_accuracy: 0.51109 | valid_accuracy: 0.50789 |  0:01:04s
# epoch 15 | loss: 1.00457 | train_accuracy: 0.51377 | valid_accuracy: 0.52368 |  0:01:08s
# epoch 16 | loss: 1.0053  | train_accuracy: 0.51225 | valid_accuracy: 0.51842 |  0:01:13s
# epoch 17 | loss: 1.00531 | train_accuracy: 0.51457 | valid_accuracy: 0.52632 |  0:01:17s
# epoch 18 | loss: 1.00379 | train_accuracy: 0.51413 | valid_accuracy: 0.52105 |  0:01:21s
# epoch 19 | loss: 1.00491 | train_accuracy: 0.51484 | valid_accuracy: 0.53421 |  0:01:25s
# epoch 20 | loss: 1.00338 | train_accuracy: 0.51502 | valid_accuracy: 0.52368 |  0:01:29s
# epoch 21 | loss: 1.00207 | train_accuracy: 0.51359 | valid_accuracy: 0.53421 |  0:01:34s
# epoch 22 | loss: 1.00249 | train_accuracy: 0.51627 | valid_accuracy: 0.52105 |  0:01:38s
# epoch 23 | loss: 1.00007 | train_accuracy: 0.51493 | valid_accuracy: 0.53684 |  0:01:43s
# epoch 24 | loss: 1.00137 | train_accuracy: 0.51681 | valid_accuracy: 0.53684 |  0:01:47s
# epoch 25 | loss: 1.00082 | train_accuracy: 0.51395 | valid_accuracy: 0.53158 |  0:01:51s
# epoch 26 | loss: 0.9998  | train_accuracy: 0.5152  | valid_accuracy: 0.52368 |  0:01:55s
# epoch 27 | loss: 0.99993 | train_accuracy: 0.5177  | valid_accuracy: 0.52895 |  0:02:00s
# epoch 28 | loss: 0.99925 | train_accuracy: 0.51377 | valid_accuracy: 0.54211 |  0:02:04s
# epoch 29 | loss: 0.99916 | train_accuracy: 0.51726 | valid_accuracy: 0.53421 |  0:02:08s
# epoch 30 | loss: 0.99577 | train_accuracy: 0.5169  | valid_accuracy: 0.53684 |  0:02:12s
# epoch 31 | loss: 0.99959 | train_accuracy: 0.51663 | valid_accuracy: 0.54474 |  0:02:17s
# epoch 32 | loss: 0.99595 | train_accuracy: 0.51529 | valid_accuracy: 0.53684 |  0:02:21s
# epoch 33 | loss: 0.99744 | train_accuracy: 0.51815 | valid_accuracy: 0.53421 |  0:02:25s
# epoch 34 | loss: 0.99731 | train_accuracy: 0.51761 | valid_accuracy: 0.53158 |  0:02:29s
# epoch 35 | loss: 0.99644 | train_accuracy: 0.51699 | valid_accuracy: 0.52632 |  0:02:34s
# epoch 36 | loss: 0.99572 | train_accuracy: 0.51949 | valid_accuracy: 0.54211 |  0:02:38s
# epoch 37 | loss: 0.99697 | train_accuracy: 0.51761 | valid_accuracy: 0.53684 |  0:02:42s
# epoch 38 | loss: 0.99878 | train_accuracy: 0.5203  | valid_accuracy: 0.52895 |  0:02:47s
# epoch 39 | loss: 0.99656 | train_accuracy: 0.51663 | valid_accuracy: 0.54211 |  0:02:51s
# epoch 40 | loss: 0.99492 | train_accuracy: 0.51842 | valid_accuracy: 0.53947 |  0:02:56s
# epoch 41 | loss: 0.99616 | train_accuracy: 0.51753 | valid_accuracy: 0.53684 |  0:03:00s
# epoch 42 | loss: 0.99765 | train_accuracy: 0.52092 | valid_accuracy: 0.55    |  0:03:04s
# epoch 43 | loss: 0.99642 | train_accuracy: 0.51905 | valid_accuracy: 0.52368 |  0:03:09s
# epoch 44 | loss: 0.9956  | train_accuracy: 0.51833 | valid_accuracy: 0.53421 |  0:03:13s
# epoch 45 | loss: 0.99495 | train_accuracy: 0.51708 | valid_accuracy: 0.53684 |  0:03:17s
# epoch 46 | loss: 0.99372 | train_accuracy: 0.52003 | valid_accuracy: 0.54211 |  0:03:21s
# epoch 47 | loss: 0.99338 | train_accuracy: 0.51994 | valid_accuracy: 0.54474 |  0:03:26s
# epoch 48 | loss: 0.99088 | train_accuracy: 0.52164 | valid_accuracy: 0.53947 |  0:03:30s
# epoch 49 | loss: 0.99428 | train_accuracy: 0.52235 | valid_accuracy: 0.54211 |  0:03:34s
# epoch 50 | loss: 0.99421 | train_accuracy: 0.52262 | valid_accuracy: 0.53684 |  0:03:39s
# epoch 51 | loss: 0.99231 | train_accuracy: 0.52092 | valid_accuracy: 0.54474 |  0:03:43s
# epoch 52 | loss: 0.99169 | train_accuracy: 0.52262 | valid_accuracy: 0.52895 |  0:03:48s
# epoch 53 | loss: 0.99189 | train_accuracy: 0.522   | valid_accuracy: 0.53421 |  0:03:52s
# epoch 54 | loss: 0.99272 | train_accuracy: 0.522   | valid_accuracy: 0.55263 |  0:03:57s
# epoch 55 | loss: 0.98985 | train_accuracy: 0.52298 | valid_accuracy: 0.54737 |  0:04:01s
# epoch 56 | loss: 0.99124 | train_accuracy: 0.52244 | valid_accuracy: 0.54211 |  0:04:06s
# epoch 57 | loss: 0.99036 | train_accuracy: 0.52217 | valid_accuracy: 0.53684 |  0:04:11s
# epoch 58 | loss: 0.99012 | train_accuracy: 0.5245  | valid_accuracy: 0.53947 |  0:04:18s
# epoch 59 | loss: 0.99357 | train_accuracy: 0.52271 | valid_accuracy: 0.52895 |  0:04:23s
# epoch 60 | loss: 0.99047 | train_accuracy: 0.52217 | valid_accuracy: 0.54211 |  0:04:27s
# epoch 61 | loss: 0.99115 | train_accuracy: 0.52289 | valid_accuracy: 0.53158 |  0:04:32s
# epoch 62 | loss: 0.9898  | train_accuracy: 0.52316 | valid_accuracy: 0.54474 |  0:04:36s
# epoch 63 | loss: 0.99117 | train_accuracy: 0.52146 | valid_accuracy: 0.54474 |  0:04:44s
# epoch 64 | loss: 0.99135 | train_accuracy: 0.52101 | valid_accuracy: 0.53684 |  0:04:48s
# epoch 65 | loss: 0.99103 | train_accuracy: 0.52459 | valid_accuracy: 0.54211 |  0:04:52s
# epoch 66 | loss: 0.98968 | train_accuracy: 0.52459 | valid_accuracy: 0.54474 |  0:04:57s
# epoch 67 | loss: 0.98899 | train_accuracy: 0.5245  | valid_accuracy: 0.53684 |  0:05:01s
# epoch 68 | loss: 0.99117 | train_accuracy: 0.52584 | valid_accuracy: 0.54211 |  0:05:05s
# epoch 69 | loss: 0.99109 | train_accuracy: 0.52647 | valid_accuracy: 0.53947 |  0:05:09s
# epoch 70 | loss: 0.98959 | train_accuracy: 0.52414 | valid_accuracy: 0.53684 |  0:05:13s
# epoch 71 | loss: 0.98983 | train_accuracy: 0.52513 | valid_accuracy: 0.54474 |  0:05:18s
# epoch 72 | loss: 0.98924 | train_accuracy: 0.52334 | valid_accuracy: 0.54211 |  0:05:22s
# epoch 73 | loss: 0.98764 | train_accuracy: 0.52477 | valid_accuracy: 0.54211 |  0:05:26s
# epoch 74 | loss: 0.98884 | train_accuracy: 0.52593 | valid_accuracy: 0.54474 |  0:05:31s
# epoch 75 | loss: 0.98777 | train_accuracy: 0.52423 | valid_accuracy: 0.54474 |  0:05:36s
# epoch 76 | loss: 0.9885  | train_accuracy: 0.52369 | valid_accuracy: 0.53947 |  0:05:41s
# epoch 77 | loss: 0.98931 | train_accuracy: 0.52459 | valid_accuracy: 0.53947 |  0:05:45s
# epoch 78 | loss: 0.98725 | train_accuracy: 0.52513 | valid_accuracy: 0.55    |  0:05:50s
# epoch 79 | loss: 0.98637 | train_accuracy: 0.5253  | valid_accuracy: 0.53947 |  0:05:54s
# epoch 80 | loss: 0.98612 | train_accuracy: 0.52387 | valid_accuracy: 0.53947 |  0:05:58s
# epoch 81 | loss: 0.98867 | train_accuracy: 0.52387 | valid_accuracy: 0.53947 |  0:06:02s
# epoch 82 | loss: 0.98798 | train_accuracy: 0.52665 | valid_accuracy: 0.54211 |  0:06:07s
# epoch 83 | loss: 0.98606 | train_accuracy: 0.52781 | valid_accuracy: 0.55526 |  0:06:11s
# epoch 84 | loss: 0.98884 | train_accuracy: 0.52709 | valid_accuracy: 0.54474 |  0:06:15s
# epoch 85 | loss: 0.98681 | train_accuracy: 0.52808 | valid_accuracy: 0.53421 |  0:06:19s
# epoch 86 | loss: 0.98724 | train_accuracy: 0.52718 | valid_accuracy: 0.55    |  0:06:24s
# epoch 87 | loss: 0.98595 | train_accuracy: 0.52736 | valid_accuracy: 0.54474 |  0:06:28s
# epoch 88 | loss: 0.98813 | train_accuracy: 0.52682 | valid_accuracy: 0.55    |  0:06:32s
# epoch 89 | loss: 0.98724 | train_accuracy: 0.52629 | valid_accuracy: 0.54211 |  0:06:36s
# epoch 90 | loss: 0.98811 | train_accuracy: 0.52879 | valid_accuracy: 0.53947 |  0:06:40s
# epoch 91 | loss: 0.98696 | train_accuracy: 0.52647 | valid_accuracy: 0.54474 |  0:06:45s
# epoch 92 | loss: 0.98463 | train_accuracy: 0.52852 | valid_accuracy: 0.54474 |  0:06:49s
# epoch 93 | loss: 0.98392 | train_accuracy: 0.52843 | valid_accuracy: 0.52895 |  0:06:53s
# epoch 94 | loss: 0.9883  | train_accuracy: 0.52852 | valid_accuracy: 0.53421 |  0:06:57s
# epoch 95 | loss: 0.98761 | train_accuracy: 0.52691 | valid_accuracy: 0.53947 |  0:07:02s
# epoch 96 | loss: 0.98528 | train_accuracy: 0.52682 | valid_accuracy: 0.53947 |  0:07:06s
# epoch 97 | loss: 0.98731 | train_accuracy: 0.5262  | valid_accuracy: 0.55789 |  0:07:10s
# epoch 98 | loss: 0.98603 | train_accuracy: 0.52843 | valid_accuracy: 0.55263 |  0:07:14s
# epoch 99 | loss: 0.98422 | train_accuracy: 0.52754 | valid_accuracy: 0.54474 |  0:07:18s
# epoch 100| loss: 0.98311 | train_accuracy: 0.53058 | valid_accuracy: 0.54211 |  0:07:23s
# epoch 101| loss: 0.98298 | train_accuracy: 0.52897 | valid_accuracy: 0.54211 |  0:07:27s
# epoch 102| loss: 0.98379 | train_accuracy: 0.52933 | valid_accuracy: 0.53421 |  0:07:31s
# epoch 103| loss: 0.98491 | train_accuracy: 0.52995 | valid_accuracy: 0.53947 |  0:07:35s
# epoch 104| loss: 0.98789 | train_accuracy: 0.52977 | valid_accuracy: 0.53947 |  0:07:39s
# epoch 105| loss: 0.98314 | train_accuracy: 0.52897 | valid_accuracy: 0.53947 |  0:07:44s
# epoch 106| loss: 0.9865  | train_accuracy: 0.52906 | valid_accuracy: 0.53684 |  0:07:48s
# epoch 107| loss: 0.98419 | train_accuracy: 0.53156 | valid_accuracy: 0.54474 |  0:07:52s
# epoch 108| loss: 0.98439 | train_accuracy: 0.53138 | valid_accuracy: 0.55263 |  0:07:56s
# epoch 109| loss: 0.98319 | train_accuracy: 0.52888 | valid_accuracy: 0.53421 |  0:08:00s
# epoch 110| loss: 0.98417 | train_accuracy: 0.53058 | valid_accuracy: 0.53684 |  0:08:05s
# epoch 111| loss: 0.98379 | train_accuracy: 0.53192 | valid_accuracy: 0.54211 |  0:08:09s
# epoch 112| loss: 0.9855  | train_accuracy: 0.53192 | valid_accuracy: 0.54211 |  0:08:13s
# epoch 113| loss: 0.98122 | train_accuracy: 0.52951 | valid_accuracy: 0.53947 |  0:08:17s
# epoch 114| loss: 0.98506 | train_accuracy: 0.52888 | valid_accuracy: 0.53421 |  0:08:22s
# epoch 115| loss: 0.98287 | train_accuracy: 0.52942 | valid_accuracy: 0.53158 |  0:08:26s
# epoch 116| loss: 0.98675 | train_accuracy: 0.53192 | valid_accuracy: 0.54737 |  0:08:30s
# epoch 117| loss: 0.98342 | train_accuracy: 0.53264 | valid_accuracy: 0.54737 |  0:08:34s
# epoch 118| loss: 0.98439 | train_accuracy: 0.5304  | valid_accuracy: 0.53421 |  0:08:38s
# epoch 119| loss: 0.98268 | train_accuracy: 0.53156 | valid_accuracy: 0.53684 |  0:08:43s
# epoch 120| loss: 0.98264 | train_accuracy: 0.53174 | valid_accuracy: 0.53947 |  0:08:47s
# epoch 121| loss: 0.98197 | train_accuracy: 0.53067 | valid_accuracy: 0.54737 |  0:08:51s
# epoch 122| loss: 0.98183 | train_accuracy: 0.53156 | valid_accuracy: 0.54474 |  0:08:55s
# epoch 123| loss: 0.98259 | train_accuracy: 0.53147 | valid_accuracy: 0.53421 |  0:09:00s
# epoch 124| loss: 0.98303 | train_accuracy: 0.53371 | valid_accuracy: 0.55    |  0:09:04s
# epoch 125| loss: 0.98029 | train_accuracy: 0.53183 | valid_accuracy: 0.53684 |  0:09:08s
# epoch 126| loss: 0.98257 | train_accuracy: 0.5329  | valid_accuracy: 0.53158 |  0:09:12s
# epoch 127| loss: 0.97999 | train_accuracy: 0.53273 | valid_accuracy: 0.52895 |  0:09:16s
# epoch 128| loss: 0.98291 | train_accuracy: 0.53237 | valid_accuracy: 0.54474 |  0:09:21s
# epoch 129| loss: 0.98176 | train_accuracy: 0.53416 | valid_accuracy: 0.53158 |  0:09:25s
# epoch 130| loss: 0.98215 | train_accuracy: 0.5338  | valid_accuracy: 0.53947 |  0:09:29s
# epoch 131| loss: 0.98071 | train_accuracy: 0.53308 | valid_accuracy: 0.53947 |  0:09:33s
# epoch 132| loss: 0.98179 | train_accuracy: 0.53416 | valid_accuracy: 0.53158 |  0:09:38s
# epoch 133| loss: 0.98027 | train_accuracy: 0.53433 | valid_accuracy: 0.54474 |  0:09:42s
# epoch 134| loss: 0.98316 | train_accuracy: 0.53129 | valid_accuracy: 0.53684 |  0:09:46s
# epoch 135| loss: 0.98026 | train_accuracy: 0.53478 | valid_accuracy: 0.54737 |  0:09:50s
# epoch 136| loss: 0.98049 | train_accuracy: 0.5346  | valid_accuracy: 0.52632 |  0:09:55s
# epoch 137| loss: 0.98376 | train_accuracy: 0.53541 | valid_accuracy: 0.54474 |  0:09:59s
# epoch 138| loss: 0.97801 | train_accuracy: 0.53442 | valid_accuracy: 0.54474 |  0:10:03s
# epoch 139| loss: 0.98087 | train_accuracy: 0.53433 | valid_accuracy: 0.54474 |  0:10:07s
# epoch 140| loss: 0.97825 | train_accuracy: 0.53371 | valid_accuracy: 0.54737 |  0:10:12s
# epoch 141| loss: 0.97919 | train_accuracy: 0.53621 | valid_accuracy: 0.54737 |  0:10:16s
# epoch 142| loss: 0.98004 | train_accuracy: 0.53326 | valid_accuracy: 0.55    |  0:10:20s
# epoch 143| loss: 0.97908 | train_accuracy: 0.53523 | valid_accuracy: 0.54737 |  0:10:24s
# epoch 144| loss: 0.98156 | train_accuracy: 0.53478 | valid_accuracy: 0.56053 |  0:10:28s
# epoch 145| loss: 0.98242 | train_accuracy: 0.53612 | valid_accuracy: 0.54737 |  0:10:33s
# epoch 146| loss: 0.9821  | train_accuracy: 0.53523 | valid_accuracy: 0.54737 |  0:10:37s
# epoch 147| loss: 0.97821 | train_accuracy: 0.53729 | valid_accuracy: 0.54211 |  0:10:41s
# epoch 148| loss: 0.97897 | train_accuracy: 0.53496 | valid_accuracy: 0.54474 |  0:10:45s
# epoch 149| loss: 0.97599 | train_accuracy: 0.5363  | valid_accuracy: 0.55526 |  0:10:49s
# epoch 150| loss: 0.97874 | train_accuracy: 0.53621 | valid_accuracy: 0.54211 |  0:10:54s
# epoch 151| loss: 0.97633 | train_accuracy: 0.53621 | valid_accuracy: 0.54737 |  0:10:58s
# epoch 152| loss: 0.97625 | train_accuracy: 0.53505 | valid_accuracy: 0.53684 |  0:11:02s
# epoch 153| loss: 0.97893 | train_accuracy: 0.53425 | valid_accuracy: 0.54737 |  0:11:06s
# epoch 154| loss: 0.97707 | train_accuracy: 0.53362 | valid_accuracy: 0.54474 |  0:11:11s
# epoch 155| loss: 0.97823 | train_accuracy: 0.53612 | valid_accuracy: 0.53684 |  0:11:15s
# epoch 156| loss: 0.97843 | train_accuracy: 0.53487 | valid_accuracy: 0.53684 |  0:11:19s
# epoch 157| loss: 0.97791 | train_accuracy: 0.53532 | valid_accuracy: 0.53947 |  0:11:23s
# epoch 158| loss: 0.97912 | train_accuracy: 0.53317 | valid_accuracy: 0.54737 |  0:11:27s
# epoch 159| loss: 0.97796 | train_accuracy: 0.53344 | valid_accuracy: 0.54211 |  0:11:32s
# epoch 160| loss: 0.97822 | train_accuracy: 0.53478 | valid_accuracy: 0.55526 |  0:11:36s
# epoch 161| loss: 0.97999 | train_accuracy: 0.53568 | valid_accuracy: 0.54737 |  0:11:40s
# epoch 162| loss: 0.98027 | train_accuracy: 0.53577 | valid_accuracy: 0.56053 |  0:11:44s
# epoch 163| loss: 0.97622 | train_accuracy: 0.53603 | valid_accuracy: 0.55263 |  0:11:48s
# epoch 164| loss: 0.97814 | train_accuracy: 0.53746 | valid_accuracy: 0.55263 |  0:11:53s
# epoch 165| loss: 0.97707 | train_accuracy: 0.53416 | valid_accuracy: 0.55263 |  0:11:57s
# epoch 166| loss: 0.97624 | train_accuracy: 0.53442 | valid_accuracy: 0.55    |  0:12:01s
# epoch 167| loss: 0.97707 | train_accuracy: 0.53711 | valid_accuracy: 0.54211 |  0:12:05s
# epoch 168| loss: 0.97524 | train_accuracy: 0.53684 | valid_accuracy: 0.55789 |  0:12:09s
# epoch 169| loss: 0.97467 | train_accuracy: 0.53782 | valid_accuracy: 0.55    |  0:12:14s
# epoch 170| loss: 0.97614 | train_accuracy: 0.53737 | valid_accuracy: 0.55263 |  0:12:18s
# epoch 171| loss: 0.97471 | train_accuracy: 0.53934 | valid_accuracy: 0.54474 |  0:12:22s
# epoch 172| loss: 0.975   | train_accuracy: 0.53711 | valid_accuracy: 0.54737 |  0:12:26s
# epoch 173| loss: 0.97569 | train_accuracy: 0.53907 | valid_accuracy: 0.54211 |  0:12:31s
# epoch 174| loss: 0.97734 | train_accuracy: 0.53881 | valid_accuracy: 0.53421 |  0:12:35s
# epoch 175| loss: 0.97481 | train_accuracy: 0.54068 | valid_accuracy: 0.54474 |  0:12:39s
# epoch 176| loss: 0.97509 | train_accuracy: 0.54292 | valid_accuracy: 0.53158 |  0:12:43s
# epoch 177| loss: 0.9772  | train_accuracy: 0.53854 | valid_accuracy: 0.54211 |  0:12:47s
# epoch 178| loss: 0.97382 | train_accuracy: 0.53961 | valid_accuracy: 0.54474 |  0:12:52s
# epoch 179| loss: 0.97706 | train_accuracy: 0.53729 | valid_accuracy: 0.54211 |  0:12:56s
# epoch 180| loss: 0.97572 | train_accuracy: 0.53755 | valid_accuracy: 0.54474 |  0:13:00s
# epoch 181| loss: 0.97574 | train_accuracy: 0.53711 | valid_accuracy: 0.54737 |  0:13:04s
# epoch 182| loss: 0.97531 | train_accuracy: 0.53997 | valid_accuracy: 0.55526 |  0:13:09s
# epoch 183| loss: 0.97568 | train_accuracy: 0.53809 | valid_accuracy: 0.55    |  0:13:13s
# epoch 184| loss: 0.97369 | train_accuracy: 0.53952 | valid_accuracy: 0.55263 |  0:13:17s
# epoch 185| loss: 0.97531 | train_accuracy: 0.53845 | valid_accuracy: 0.55    |  0:13:21s
# epoch 186| loss: 0.97347 | train_accuracy: 0.53898 | valid_accuracy: 0.53684 |  0:13:25s
# epoch 187| loss: 0.97295 | train_accuracy: 0.53916 | valid_accuracy: 0.53421 |  0:13:30s
# epoch 188| loss: 0.97474 | train_accuracy: 0.54024 | valid_accuracy: 0.53947 |  0:13:34s
# epoch 189| loss: 0.97478 | train_accuracy: 0.54033 | valid_accuracy: 0.52368 |  0:13:38s
# epoch 190| loss: 0.9725  | train_accuracy: 0.5405  | valid_accuracy: 0.54474 |  0:13:42s
# epoch 191| loss: 0.97075 | train_accuracy: 0.53925 | valid_accuracy: 0.52105 |  0:13:47s
# epoch 192| loss: 0.97755 | train_accuracy: 0.53988 | valid_accuracy: 0.53421 |  0:13:51s
# epoch 193| loss: 0.97219 | train_accuracy: 0.53898 | valid_accuracy: 0.52368 |  0:13:55s
# epoch 194| loss: 0.97527 | train_accuracy: 0.53934 | valid_accuracy: 0.54211 |  0:13:59s
# epoch 195| loss: 0.97595 | train_accuracy: 0.53934 | valid_accuracy: 0.52895 |  0:14:03s
# epoch 196| loss: 0.97322 | train_accuracy: 0.54077 | valid_accuracy: 0.53947 |  0:14:08s
# epoch 197| loss: 0.9704  | train_accuracy: 0.54104 | valid_accuracy: 0.54211 |  0:14:12s
# epoch 198| loss: 0.97236 | train_accuracy: 0.53854 | valid_accuracy: 0.55    |  0:14:16s
# epoch 199| loss: 0.97018 | train_accuracy: 0.54077 | valid_accuracy: 0.53421 |  0:14:20s
# epoch 200| loss: 0.9727  | train_accuracy: 0.53916 | valid_accuracy: 0.53421 |  0:14:25s
# epoch 201| loss: 0.96901 | train_accuracy: 0.54059 | valid_accuracy: 0.55    |  0:14:29s
# epoch 202| loss: 0.97284 | train_accuracy: 0.53827 | valid_accuracy: 0.54737 |  0:14:33s
# epoch 203| loss: 0.96978 | train_accuracy: 0.54229 | valid_accuracy: 0.54474 |  0:14:37s
# epoch 204| loss: 0.9706  | train_accuracy: 0.54077 | valid_accuracy: 0.53947 |  0:14:41s
# epoch 205| loss: 0.974   | train_accuracy: 0.53988 | valid_accuracy: 0.55    |  0:14:46s
# epoch 206| loss: 0.96883 | train_accuracy: 0.54095 | valid_accuracy: 0.55263 |  0:14:50s
# epoch 207| loss: 0.97343 | train_accuracy: 0.54202 | valid_accuracy: 0.54211 |  0:14:54s
# epoch 208| loss: 0.97307 | train_accuracy: 0.5414  | valid_accuracy: 0.53947 |  0:14:58s
# epoch 209| loss: 0.97175 | train_accuracy: 0.54024 | valid_accuracy: 0.53421 |  0:15:02s
# epoch 210| loss: 0.97276 | train_accuracy: 0.54202 | valid_accuracy: 0.54474 |  0:15:07s
# epoch 211| loss: 0.96846 | train_accuracy: 0.54158 | valid_accuracy: 0.53947 |  0:15:11s
# epoch 212| loss: 0.97217 | train_accuracy: 0.54131 | valid_accuracy: 0.54211 |  0:15:15s
# epoch 213| loss: 0.96982 | train_accuracy: 0.54086 | valid_accuracy: 0.53421 |  0:15:19s
# epoch 214| loss: 0.97073 | train_accuracy: 0.54068 | valid_accuracy: 0.53947 |  0:15:23s
# epoch 215| loss: 0.97735 | train_accuracy: 0.53988 | valid_accuracy: 0.53947 |  0:15:28s
# epoch 216| loss: 0.971   | train_accuracy: 0.54417 | valid_accuracy: 0.54737 |  0:15:32s
# epoch 217| loss: 0.97229 | train_accuracy: 0.54399 | valid_accuracy: 0.54737 |  0:15:36s
# epoch 218| loss: 0.9705  | train_accuracy: 0.54363 | valid_accuracy: 0.55263 |  0:15:40s
# epoch 219| loss: 0.97426 | train_accuracy: 0.53943 | valid_accuracy: 0.54737 |  0:15:45s
# epoch 220| loss: 0.97373 | train_accuracy: 0.54158 | valid_accuracy: 0.55263 |  0:15:49s
# epoch 221| loss: 0.97256 | train_accuracy: 0.54185 | valid_accuracy: 0.54474 |  0:15:53s
# epoch 222| loss: 0.9737  | train_accuracy: 0.54363 | valid_accuracy: 0.55    |  0:15:57s
# epoch 223| loss: 0.96939 | train_accuracy: 0.54489 | valid_accuracy: 0.55263 |  0:16:02s
# epoch 224| loss: 0.97077 | train_accuracy: 0.54524 | valid_accuracy: 0.54737 |  0:16:06s
# epoch 225| loss: 0.97617 | train_accuracy: 0.54685 | valid_accuracy: 0.56053 |  0:16:10s
# epoch 226| loss: 0.96963 | train_accuracy: 0.54542 | valid_accuracy: 0.53421 |  0:16:14s
# epoch 227| loss: 0.97321 | train_accuracy: 0.54641 | valid_accuracy: 0.54211 |  0:16:18s
# epoch 228| loss: 0.97245 | train_accuracy: 0.54471 | valid_accuracy: 0.53421 |  0:16:23s
# epoch 229| loss: 0.9707  | train_accuracy: 0.54587 | valid_accuracy: 0.53947 |  0:16:27s
# epoch 230| loss: 0.96961 | train_accuracy: 0.54775 | valid_accuracy: 0.54737 |  0:16:32s
# epoch 231| loss: 0.96944 | train_accuracy: 0.54605 | valid_accuracy: 0.54211 |  0:16:36s
# epoch 232| loss: 0.96781 | train_accuracy: 0.54748 | valid_accuracy: 0.53684 |  0:16:40s
# epoch 233| loss: 0.96786 | train_accuracy: 0.5473  | valid_accuracy: 0.53421 |  0:16:45s
# epoch 234| loss: 0.96954 | train_accuracy: 0.54381 | valid_accuracy: 0.52895 |  0:16:49s
# epoch 235| loss: 0.969   | train_accuracy: 0.54363 | valid_accuracy: 0.53684 |  0:16:53s
# epoch 236| loss: 0.97168 | train_accuracy: 0.54614 | valid_accuracy: 0.53684 |  0:16:58s
# epoch 237| loss: 0.96776 | train_accuracy: 0.54506 | valid_accuracy: 0.53684 |  0:17:02s
# epoch 238| loss: 0.97061 | train_accuracy: 0.5456  | valid_accuracy: 0.54474 |  0:17:06s
# epoch 239| loss: 0.96821 | train_accuracy: 0.54596 | valid_accuracy: 0.53947 |  0:17:11s
# epoch 240| loss: 0.97156 | train_accuracy: 0.5448  | valid_accuracy: 0.53947 |  0:17:15s
# epoch 241| loss: 0.97124 | train_accuracy: 0.54426 | valid_accuracy: 0.53684 |  0:17:19s
# epoch 242| loss: 0.96768 | train_accuracy: 0.54489 | valid_accuracy: 0.53158 |  0:17:23s
# epoch 243| loss: 0.96657 | train_accuracy: 0.54909 | valid_accuracy: 0.52632 |  0:17:27s
# epoch 244| loss: 0.9683  | train_accuracy: 0.54632 | valid_accuracy: 0.52895 |  0:17:32s
#
# Early stopping occurred at epoch 244 with best_epoch = 144 and best_valid_accuracy = 0.56053
# /Users/gustavofernandez/Desktop/iPre-resultados-deportivos/env/lib/python3.8/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
print("classification report")
print(classification_report(y_test, pred))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.58      0.88      0.70       184
#            2       0.51      0.48      0.50       109
#
#     accuracy                           0.56       380
#    macro avg       0.36      0.45      0.40       380
# weighted avg       0.43      0.56      0.48       380

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')


    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

cnf_matrix = confusion_matrix(y_test, pred)
classes = np.unique(y_train)
np.set_printoptions(precision=2)
# Plot normalized confusion matrix
plt.figure(figsize=(5,5))

plot_confusion_matrix(cnf_matrix, classes=classes, normalize=True, title='Normalized confusion matrix')

plt.show()
# Out:
# Normalized confusion matrix
