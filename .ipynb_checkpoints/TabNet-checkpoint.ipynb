# %%
from pytorch_tabnet.tab_model import TabNetClassifier

import os
import torch
import pandas as pd
import numpy as np
 
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#Usamos el GPU si esta disponible, mps porque es apple silicon.
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f"using {device}")

#también hay que mover los datos a la gpu.
# Out:
# using mps

# %% [markdown]
# Cargar los datos y estructurarlos para entrenar el modelo.
#
# Voy a usar los datos que usó Diego.

# %%
folder = "Data"
match_file = "estadisticas_partidos.csv"

path_matches = os.path.join(folder, match_file)
matches = pd.read_csv(path_matches)

# %%
print(matches.columns.values)
print(len(matches.columns.values))
# Out:
# ['team_home' 'team_away' 'score_home' 'score_away' 'expected_goals_home'
#  'expected_goals_away' 'posession_home' 'posession_away'
#  'total_shots_home' 'total_shots_away' 'shots_on_target_home'
#  'shots_on_target_away' 'shots_off_target_home' 'shots_off_target_away'
#  'blocked_shots_home' 'blocked_shots_away' 'corner_kicks_home'
#  'corner_kicks_away' 'offsides_home' 'offsides_away' 'fouls_home'
#  'fouls_away' 'yellow_cards_home' 'yellow_cards_away' 'red_cards_home'
#  'red_cards_away' 'free_kicks_home' 'free_kicks_away' 'throw_ins_home'
#  'throw_ins_away' 'goal_kicks_home' 'goal_kicks_away'
#  'shots_inside_box_home' 'shots_inside_box_away' 'shots_outside_box_home'
#  'shots_outside_box_away' 'goalkeeper_saves_home' 'goalkeeper_saves_away'
#  'passes_home' 'passes_away' 'accurate_passes_home' 'accurate_passes_away'
#  'long_balls_home' 'long_balls_away' 'crosses_home' 'crosses_away'
#  'dribbles_home' 'dribbles_away' 'possesion_lost_home'
#  'possesion_lost_away' 'duels_won_home' 'duels_won_away'
#  'aerials_won_home' 'aerials_won_away' 'tackles_home' 'tackles_away'
#  'interceptions_home' 'interceptions_away' 'clearences_home'
#  'clearences_away']
# 60

# %%
matches.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   team_home               240 non-null    object
#  1   team_away               240 non-null    object
#  2   score_home              240 non-null    int64
#  3   score_away              240 non-null    int64
#  4   expected_goals_home     240 non-null    float64
#  5   expected_goals_away     240 non-null    float64
#  6   posession_home          240 non-null    int64
#  7   posession_away          240 non-null    int64
#  8   total_shots_home        240 non-null    int64
#  9   total_shots_away        240 non-null    int64
#  10  shots_on_target_home    240 non-null    int64
#  11  shots_on_target_away    240 non-null    int64
#  12  shots_off_target_home   240 non-null    int64
#  13  shots_off_target_away   240 non-null    int64
#  14  blocked_shots_home      240 non-null    int64
#  15  blocked_shots_away      240 non-null    int64
#  16  corner_kicks_home       240 non-null    int64
#  17  corner_kicks_away       240 non-null    int64
#  18  offsides_home           240 non-null    int64
#  19  offsides_away           240 non-null    int64
#  20  fouls_home              240 non-null    int64
#  21  fouls_away              240 non-null    int64
#  22  yellow_cards_home       240 non-null    int64
#  23  yellow_cards_away       240 non-null    int64
#  24  red_cards_home          240 non-null    int64
#  25  red_cards_away          240 non-null    int64
#  26  free_kicks_home         240 non-null    int64
#  27  free_kicks_away         240 non-null    int64
#  28  throw_ins_home          240 non-null    int64
#  29  throw_ins_away          240 non-null    int64
#  30  goal_kicks_home         240 non-null    int64
#  31  goal_kicks_away         240 non-null    int64
#  32  shots_inside_box_home   240 non-null    int64
#  33  shots_inside_box_away   240 non-null    int64
#  34  shots_outside_box_home  240 non-null    int64
#  35  shots_outside_box_away  240 non-null    int64
#  36  goalkeeper_saves_home   240 non-null    int64
#  37  goalkeeper_saves_away   240 non-null    int64
#  38  passes_home             240 non-null    int64
#  39  passes_away             240 non-null    int64
#  40  accurate_passes_home    240 non-null    int64
#  41  accurate_passes_away    240 non-null    int64
#  42  long_balls_home         240 non-null    int64
#  43  long_balls_away         240 non-null    int64
#  44  crosses_home            240 non-null    int64
#  45  crosses_away            240 non-null    int64
#  46  dribbles_home           240 non-null    int64
#  47  dribbles_away           240 non-null    int64
#  48  possesion_lost_home     240 non-null    int64
#  49  possesion_lost_away     240 non-null    int64
#  50  duels_won_home          240 non-null    int64
#  51  duels_won_away          240 non-null    int64
#  52  aerials_won_home        240 non-null    int64
#  53  aerials_won_away        240 non-null    int64
#  54  tackles_home            240 non-null    int64
#  55  tackles_away            240 non-null    int64
#  56  interceptions_home      240 non-null    int64
#  57  interceptions_away      240 non-null    int64
#  58  clearences_home         240 non-null    int64
#  59  clearences_away         240 non-null    int64
# dtypes: float64(2), int64(56), object(2)
# memory usage: 112.6+ KB

# %%
#Aqui agrega la columna de resultados

results = []

for index in matches.index:

    match = matches.loc[index]
    if match["score_home"] > match["score_away"]:
        results.append(1)
    elif match["score_home"] < match["score_away"]:
        results.append(2)
    else:
        results.append(0)

matches["result"] = results

# %%
matches.head()
# Out:
#              team_home                team_away  score_home  score_away  \
# 0         Curicó Unido                Colo Colo           0           1
# 1           Huachipato           Audax Italiano           2           0
# 2       Unión Española                 Cobresal           1           0
# 3     Deportes Copiapó  Everton de Viña del Mar           2           0
# 4  Deportes Magallanes           Coquimbo Unido           2           3
#
#    expected_goals_home  expected_goals_away  posession_home  posession_away  \
# 0                 0.07                 2.31              32              68
# 1                 1.34                 0.45              64              36
# 2                 1.09                 0.54              65              35
# 3                 1.21                 0.59              36              64
# 4                 1.62                 1.82              57              43
#
#    total_shots_home  total_shots_away  ...  duels_won_away  aerials_won_home  \
# 0                 5                20  ...              33                 4
# 1                12                13  ...              35                13
# 2                26                 9  ...              66                18
# 3                10                12  ...              35                11
# 4                13                15  ...              32                 9
#
#    aerials_won_away  tackles_home  tackles_away  interceptions_home  \
# 0                11            11             8                   5
# 1                 9            12            12                   7
# 2                14            18            19                   3
# 3                 9            13             9                   7
# 4                11            10             6                   5
#
#    interceptions_away  clearences_home  clearences_away  result
# 0                   8               23                8       2
# 1                   4               19               28       1
# 2                  11               24               24       1
# 3                   2               28               13       1
# 4                   1               16               20       2
#
# [5 rows x 61 columns]

# %%
matches.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 61 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   team_home               240 non-null    object
#  1   team_away               240 non-null    object
#  2   score_home              240 non-null    int64
#  3   score_away              240 non-null    int64
#  4   expected_goals_home     240 non-null    float64
#  5   expected_goals_away     240 non-null    float64
#  6   posession_home          240 non-null    int64
#  7   posession_away          240 non-null    int64
#  8   total_shots_home        240 non-null    int64
#  9   total_shots_away        240 non-null    int64
#  10  shots_on_target_home    240 non-null    int64
#  11  shots_on_target_away    240 non-null    int64
#  12  shots_off_target_home   240 non-null    int64
#  13  shots_off_target_away   240 non-null    int64
#  14  blocked_shots_home      240 non-null    int64
#  15  blocked_shots_away      240 non-null    int64
#  16  corner_kicks_home       240 non-null    int64
#  17  corner_kicks_away       240 non-null    int64
#  18  offsides_home           240 non-null    int64
#  19  offsides_away           240 non-null    int64
#  20  fouls_home              240 non-null    int64
#  21  fouls_away              240 non-null    int64
#  22  yellow_cards_home       240 non-null    int64
#  23  yellow_cards_away       240 non-null    int64
#  24  red_cards_home          240 non-null    int64
#  25  red_cards_away          240 non-null    int64
#  26  free_kicks_home         240 non-null    int64
#  27  free_kicks_away         240 non-null    int64
#  28  throw_ins_home          240 non-null    int64
#  29  throw_ins_away          240 non-null    int64
#  30  goal_kicks_home         240 non-null    int64
#  31  goal_kicks_away         240 non-null    int64
#  32  shots_inside_box_home   240 non-null    int64
#  33  shots_inside_box_away   240 non-null    int64
#  34  shots_outside_box_home  240 non-null    int64
#  35  shots_outside_box_away  240 non-null    int64
#  36  goalkeeper_saves_home   240 non-null    int64
#  37  goalkeeper_saves_away   240 non-null    int64
#  38  passes_home             240 non-null    int64
#  39  passes_away             240 non-null    int64
#  40  accurate_passes_home    240 non-null    int64
#  41  accurate_passes_away    240 non-null    int64
#  42  long_balls_home         240 non-null    int64
#  43  long_balls_away         240 non-null    int64
#  44  crosses_home            240 non-null    int64
#  45  crosses_away            240 non-null    int64
#  46  dribbles_home           240 non-null    int64
#  47  dribbles_away           240 non-null    int64
#  48  possesion_lost_home     240 non-null    int64
#  49  possesion_lost_away     240 non-null    int64
#  50  duels_won_home          240 non-null    int64
#  51  duels_won_away          240 non-null    int64
#  52  aerials_won_home        240 non-null    int64
#  53  aerials_won_away        240 non-null    int64
#  54  tackles_home            240 non-null    int64
#  55  tackles_away            240 non-null    int64
#  56  interceptions_home      240 non-null    int64
#  57  interceptions_away      240 non-null    int64
#  58  clearences_home         240 non-null    int64
#  59  clearences_away         240 non-null    int64
#  60  result                  240 non-null    int64
# dtypes: float64(2), int64(57), object(2)
# memory usage: 114.5+ KB

# %%
#Cantidad de partidos por resultado (local, empate, visita)

for i in range(0,3):
    cantidad = matches[matches["result"]==i].shape[0]
    print(f"Resultado {i}, hay: {cantidad} partidos")
num = 97/(59+97+84)
print(num)
# Out:
# Resultado 0, hay: 59 partidos
# Resultado 1, hay: 97 partidos
# Resultado 2, hay: 84 partidos
# 0.4041666666666667

# %%
result = matches["result"]
matches = matches.drop(columns = ["team_home", "team_away", "result", "score_home", "score_away"])
matches.head()

columnas_categoricas = matches.select_dtypes(include=['object']).columns.tolist()

print("Columnas categóricas:")
print(columnas_categoricas)
# Out:
# Columnas categóricas:
# []

# %%
# Convertir columnas categoricas a numericas

#col = LabelEncoder().fit(matches["columna_tabla"])
#data["columna_tabla"] = col.transform(matches["columna_tabla"])

# %%
X = matches.to_numpy()
scaler = StandardScaler()
X_escalados = scaler.fit_transform(X)
y = result

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_escalados, y, test_size=0.3, random_state = 1, stratify=y)

# %%
kfold = KFold(n_splits=5)

y_true_all = []
y_pred_all = []

for train_index, test_index in kfold.split(X_escalados):
    X_train, X_test = X_escalados[train_index], X_escalados[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf = TabNetClassifier(
        optimizer_fn=torch.optim.Adam,
        optimizer_params=dict(lr=1e-3),
        scheduler_params={"step_size":50, # how to use learning rate scheduler
                            "gamma":0.9},
        scheduler_fn=torch.optim.lr_scheduler.StepLR,
        mask_type='entmax', # "sparsemax" "entmax"
        )
        
    clf.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)], 
        eval_name=['train', 'valid'], 
        eval_metric=['accuracy'], 
        max_epochs=1000 , patience=100, 
        batch_size=28, drop_last=False)

    pred = clf.predict(X_test)
    # Almacenar las predicciones y las etiquetas verdaderas de este fold
    y_true_all.extend(y_test)
    y_pred_all.extend(pred)
# Out:
# /Users/gustavofernandez/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[103], line 18
#       8 y_train, y_test = y[train_index], y[test_index]
#       9 clf = TabNetClassifier(
#      10     optimizer_fn=torch.optim.Adam,
#      11     optimizer_params=dict(lr=1e-3),
#    (...)
#      15     mask_type='sigmoid', # "sparsemax" "entmax" "sigmoid"
#      16     )
# ---> 18 clf.fit(X_train, y_train,
#      19     eval_set=[(X_train, y_train), (X_test, y_test)],
#      20     eval_name=['train', 'valid'],
#      21     eval_metric=['accuracy'],
#      22     max_epochs=1000 , patience=100,
#      23     batch_size=28, drop_last=False)
#      25 pred = clf.predict(X_test)
#      26 # Almacenar las predicciones y las etiquetas verdaderas de este fold
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/abstract_model.py:240, in TabModel.fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations, compute_importance)
#     236     self.__update__(**from_unsupervised.get_params())
#     238 if not hasattr(self, "network") or not warm_start:
#     239     # model has never been fitted before of warm_start is False
# --> 240     self._set_network()
#     241 self._update_network_params()
#     242 self._set_metrics(eval_metric, eval_names)
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/abstract_model.py:605, in TabModel._set_network(self)
#     601 torch.manual_seed(self.seed)
#     603 self.group_matrix = create_group_matrix(self.grouped_features, self.input_dim)
# --> 605 self.network = tab_network.TabNet(
#     606     self.input_dim,
#     607     self.output_dim,
#     608     n_d=self.n_d,
#     609     n_a=self.n_a,
#     610     n_steps=self.n_steps,
#     611     gamma=self.gamma,
#     612     cat_idxs=self.cat_idxs,
#     613     cat_dims=self.cat_dims,
#     614     cat_emb_dim=self.cat_emb_dim,
#     615     n_independent=self.n_independent,
#     616     n_shared=self.n_shared,
#     617     epsilon=self.epsilon,
#     618     virtual_batch_size=self.virtual_batch_size,
#     619     momentum=self.momentum,
#     620     mask_type=self.mask_type,
#     621     group_attention_matrix=self.group_matrix.to(self.device),
#     622 ).to(self.device)
#     624 self.reducing_matrix = create_explain_matrix(
#     625     self.network.input_dim,
#     626     self.network.cat_emb_dim,
#     627     self.network.cat_idxs,
#     628     self.network.post_embed_dim,
#     629 )
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/tab_network.py:598, in TabNet.__init__(self, input_dim, output_dim, n_d, n_a, n_steps, gamma, cat_idxs, cat_dims, cat_emb_dim, n_independent, n_shared, epsilon, virtual_batch_size, momentum, mask_type, group_attention_matrix)
#     591 self.embedder = EmbeddingGenerator(input_dim,
#     592                                    cat_dims,
#     593                                    cat_idxs,
#     594                                    cat_emb_dim,
#     595                                    group_attention_matrix)
#     596 self.post_embed_dim = self.embedder.post_embed_dim
# --> 598 self.tabnet = TabNetNoEmbeddings(
#     599     self.post_embed_dim,
#     600     output_dim,
#     601     n_d,
#     602     n_a,
#     603     n_steps,
#     604     gamma,
#     605     n_independent,
#     606     n_shared,
#     607     epsilon,
#     608     virtual_batch_size,
#     609     momentum,
#     610     mask_type,
#     611     self.embedder.embedding_group_matrix
#     612 )
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/tab_network.py:464, in TabNetNoEmbeddings.__init__(self, input_dim, output_dim, n_d, n_a, n_steps, gamma, n_independent, n_shared, epsilon, virtual_batch_size, momentum, mask_type, group_attention_matrix)
#     461 self.mask_type = mask_type
#     462 self.initial_bn = BatchNorm1d(self.input_dim, momentum=0.01)
# --> 464 self.encoder = TabNetEncoder(
#     465     input_dim=input_dim,
#     466     output_dim=output_dim,
#     467     n_d=n_d,
#     468     n_a=n_a,
#     469     n_steps=n_steps,
#     470     gamma=gamma,
#     471     n_independent=n_independent,
#     472     n_shared=n_shared,
#     473     epsilon=epsilon,
#     474     virtual_batch_size=virtual_batch_size,
#     475     momentum=momentum,
#     476     mask_type=mask_type,
#     477     group_attention_matrix=group_attention_matrix
#     478 )
#     480 if self.is_multi_task:
#     481     self.multi_task_mappings = torch.nn.ModuleList()
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/tab_network.py:150, in TabNetEncoder.__init__(self, input_dim, output_dim, n_d, n_a, n_steps, gamma, n_independent, n_shared, epsilon, virtual_batch_size, momentum, mask_type, group_attention_matrix)
#     141 for step in range(n_steps):
#     142     transformer = FeatTransformer(
#     143         self.input_dim,
#     144         n_d + n_a,
#    (...)
#     148         momentum=momentum,
#     149     )
# --> 150     attention = AttentiveTransformer(
#     151         n_a,
#     152         self.attention_dim,
#     153         group_matrix=group_attention_matrix,
#     154         virtual_batch_size=self.virtual_batch_size,
#     155         momentum=momentum,
#     156         mask_type=self.mask_type,
#     157     )
#     158     self.feat_transformers.append(transformer)
#     159     self.att_transformers.append(attention)
#
# File ~/Desktop/pytorch-test/env/lib/python3.8/site-packages/pytorch_tabnet/tab_network.py:663, in AttentiveTransformer.__init__(self, input_dim, group_dim, group_matrix, virtual_batch_size, momentum, mask_type)
#     661     self.selector = sparsemax.Entmax15(dim=-1)
#     662 else:
# --> 663     raise NotImplementedError(
#     664         "Please choose either sparsemax" + "or entmax as masktype"
#     665     )
#
# NotImplementedError: Please choose either sparsemaxor entmax as masktype

# %%
print("classification report")
print(classification_report(y_true_all, y_pred_all))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.39      0.22      0.28        59
#            1       0.55      0.72      0.62        97
#            2       0.57      0.54      0.55        84
#
#     accuracy                           0.53       240
#    macro avg       0.50      0.49      0.49       240
# weighted avg       0.52      0.53      0.51       240
